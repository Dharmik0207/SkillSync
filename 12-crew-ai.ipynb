# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Evolution of AI:
# - Conditions-Based Programming: We started with basic programming logic using "if-then" conditions.
#
# - Machine Learning (ML): For structured data (like spreadsheets), we used ML algorithms from scikit-learn to find patterns between inputs and outputs.
#
# - Deep Learning: For unstructured data (images, text), we applied neural networks to detect complex patterns, using libraries like TensorFlow and PyTorch.
#
# - Large Language Models (LLMs): We trained huge models on vast amounts of text to enable them to understand and generate human language.
#
# - Retrieval Augmented Generation (RAG): To solve the problem of LLMs not knowing about new documents, we added RAG, which allows them to find and use information from specific, unseen documents.
#
# - Chains: We built sequential or parallel chains to perform multi-step tasks. For example, we first used an API to get data and then sent that data to an LLM to generate a clear response.
#
# - AI Agents: We equipped LLMs with various tools (like Python functions for databases or APIs) so they could autonomously interact with them to complete tasks.
#
# - Model Context Protocol (MCP): We separated the LLMs from the tools and integrated them with MCP servers to make the code reusable.
#
# - Agent-to-Agent (A2A) Protocol: We created a protocol to allow different AI agents to communicate and interact with each other.

# %% [markdown]
# ## Crew AI:

# %% [markdown]
# - Agents: It uses the LLM, Tools, background, role.
# - Tasks: It uses agents and produces output.
# - Crew: It has various agents to accomplish a mission.

# %%
# !pip install crewai -q
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from crewai import LLM
from crewai import Agent, Task, Crew

# %%
llm = LLM(model="gpt-4o-mini")

# %%
response = llm.call("Define Justice in 2 lines")

# %%
response
# Out:
# 'Justice is the principle of fairness and equality, ensuring that individuals receive what they are due based on their actions and circumstances. It upholds the rule of law, protecting rights while promoting accountability and societal harmony.'

# %%
agent1 = Agent(
    role = "English Playwriter",
    backstory = "You are an amazing Nobel Winner Playwriter whose IQ is equivalent to Shakespeare in language", 
    verbose = True,
    llm = llm,
    goal = "You need to produce a good play in less than 10 lines"
)

# %%
task1 = Task(
    description="Create a short play on topic : {topic}",
    agent=agent1,
    expected_output="It is well structured play",
)

# %%
crew = Crew(
    agents=[agent1],
    tasks=[task1],
)

# %%
output = crew.kickoff(
    inputs = {
        "topic": "guy with regret"
    }
)
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: English Playwriter                                                                                      │
# │                                                                                                                 │
# │  Task: Create a short play on topic : guy with regret                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: English Playwriter                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Title: Shadows of Regret**                                                                                   │
# │                                                                                                                 │
# │  **Characters:**                                                                                                │
# │  - JAMES: A weary man in his thirties, burdened with regret.                                                    │
# │  - EMMA: A ghostly figure of his past, vibrant and full of life.                                                │
# │                                                                                                                 │
# │  **Setting:** An abandoned park at twilight, memories swirling like fallen leaves.                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  *(JAMES stands center stage, staring at the ground, as if searching for lost treasures among the dust. The     │
# │  silence is heavy until EMMA’s laughter echoes from the shadows.)*                                              │
# │                                                                                                                 │
# │  **EMMA:** *(steps into light)* Oh, James! Do you still tread these paths, lost in what could have been?        │
# │                                                                                                                 │
# │  **JAMES:** *(looking up, startled)* Emma? You linger here, a wisp of my foolishness.                           │
# │                                                                                                                 │
# │  **EMMA:** No, my dear. I am the echoes of your choices, the laughter stifled and the dreams forsaken.          │
# │                                                                                                                 │
# │  **JAMES:** I let you slip away, thinking there’d be time—a foolish man I was!                                  │
# │                                                                                                                 │
# │  **EMMA:** Time is but a thief. Regret festers in places unvisited. What haunts you most?                       │
# │                                                                                                                 │
# │  **JAMES:** The words unspoken, the moments shared but never cherished! I let the sun set on us, believing it   │
# │  would rise again—                                                                                              │
# │                                                                                                                 │
# │  **EMMA:** *(gentle smile)* It is never too late to redeem, James. Recall the warmth. Find solace in the        │
# │  splendid chaos of your heart!                                                                                  │
# │                                                                                                                 │
# │  **JAMES:** *(sighs deeply, a flicker of hope in his eyes)* Perhaps, even shadows can teach us how to embrace   │
# │  the light…                                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  *(The lights fade, leaving JAMES standing alone but with a newfound glimmer of resolve in his eyes, the        │
# │  park's deep silence turning into a promise of a new dawn.)*                                                    │
# │                                                                                                                 │
# │  **[CURTAIN]**                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(output)
# Out:
# **Title: Shadows of Regret**
#
# **(A dimly lit stage, center a solitary man, JAMES, seated at an old wooden table, a glass of whiskey in his hand. The sound of a clock ticks ominously in the background.)**
#
# **JAMES:**
# *(To audience, voice laden with sorrow)*
# In the mirror, a stranger stares back,
# Echoes of laughter now drowned in the dark.
# Once was a time, dreams danced like fire,
# But I stifled their flame, swallowed desire.
#
# *(He stands, pacing, as memories flicker across his face)*
# A love I forsook, a promise I broke,
# Time slipped through fingers like shadows of smoke.
# Now regret’s cruel mistress has drawn her last breath,
# And I’m haunted by visions of life met with death.
#
# **(He collapses into the chair, staring into the glass, tears threatening to spill.)**
# What solace remains, when redemption is lost?
# A man forged by choices, now counting the cost.
#
# **(The clock strikes a final hour as the light fades, leaving JAMES in darkness, a ghost of the man he once was.)**
# *(Curtain falls.)*

# %% [markdown]
# ## SkillSync - Multi AI Agent application:
#
# We have built a resume shortlist application, called SkillSync. We used crew ai for this application.
#
# HR team provides resume and job description for the role. Then, we have an agent whose job is to read the resume and summarise the skills. Then we have another agent which reads the job description and summarise the job description and enrich text for skills. Then we have one more agent which analyses the output from both agents, resume skills and jd skills, then it'll give the output as best match, ok to go, irrelevant profile. We integrated these agents with kickoff method in crew ai. We created REST API using fast api framework and used gpt 4o as llm. We hosted this app on Azure Functions.

# %%
# Define the agents

resume_reader = Agent(
    role="Resume Reader",
    goal="Read a resume and extract all skills mentioned.",
    backstory="You are an expert at parsing resumes to find and list all technical and soft skills.",
    llm=llm,
    verbose=True,
    allow_delegation=False
)

jd_analyst = Agent(
    role="Job Description Analyst",
    goal="Read a job description, summarize the required skills, and enrich the text.",
    backstory="You are a skilled recruiter who understands job descriptions deeply and can identify core skills and keywords.",
    llm=llm,
    verbose=True,
    allow_delegation=False
)

matcher = Agent(
    role="Profile Matcher",
    goal="Analyze the skills from a resume and a job description and determine the best match level.",
    backstory="You are a professional HR specialist who makes final decisions on candidate suitability based on a skills comparison.",
    llm=llm,
    verbose=True,
    allow_delegation=False
)

# %%
# Define the tasks

read_resume_task = Task(
    description=(
        "Read the provided resume text below and generate a concise summary of the candidate's skills, formatted as a bulleted list. "
        "Resume Text: {resume_text}"
    ),
    agent=resume_reader,
    expected_output="A bulleted list of skills extracted from the resume.",
)

analyze_jd_task = Task(
    description=(
        "Read the job description text below. Summarize the key skills and qualifications required for the role. "
        "Job Description Text: {jd_text}"
    ),
    agent=jd_analyst,
    expected_output="A summary of required skills from the job description.",
)

match_profile_task = Task(
    description=(
        "Compare the skills from the resume summary with the required skills from the job description summary. "
        "Based on the comparison, classify the candidate's profile into one of three categories: 'Best Match', 'OK to Go', or 'Irrelevant Profile'. "
        "Provide a brief, one-sentence justification for your classification. "
        "Resume Skills: {resume_skills_summary}\n"
        "Job Description Skills: {jd_skills_summary}"
    ),
    agent=matcher,
    expected_output="The classification (Best Match, OK to Go, or Irrelevant Profile) with a brief justification.",
)

# %%
# Define the crew

skill_sync_crew = Crew(
    agents=[resume_reader, jd_analyst, matcher],
    tasks=[read_resume_task, analyze_jd_task, match_profile_task],
    verbose=True
)

# %%
import pdfplumber

def extract_text_from_pdf(file):
    with pdfplumber.open(file) as pdf_file:
        text_extracted = []
        for page in pdf_file.pages:
            tables = page.extract_tables()
            text_extracted.append(
                {
                    "text": page.extract_text(),
                    "tables": tables
                }
            )
        return "\n\n".join(map(str, text_extracted))

# %%
resume = r"C:\Users\junai\Downloads\Junaid_2025_APR_CV_Gen (1).pdf"
resume_text = extract_text_from_pdf(resume)
jd_text = """
Responsibilities

Advise clients on AI and data strategy from pilot to enterprise adoption
Define AI roadmaps and oversee delivery across industries
Build relationships with senior business leaders
Lead teams in designing and deploying innovative AI solutions


Requirements

Experience in analytics, data science, or AI strategy
Strong knowledge of cloud ecosystems and AI tools
Excellent stakeholder engagement skills
Background in consulting or advisory roles


Benefits

Salary up to €90,000
Access to major enterprises across finance, healthcare, and automotive
Career development in a growing AI practice
Flexible work setup within an international team

"""

# %%
result = skill_sync_crew.kickoff(inputs={
    "resume_text": resume_text,
    "jd_text": jd_text,
    "resume_skills_summary": "",  # This will be filled by the first task's output
    "jd_skills_summary": ""       # This will be filled by the second task's output
})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 82cda1dd-12b8-4fbf-97c9-7f9e79ac15d8                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resume Reader                                                                                           │
# │                                                                                                                 │
# │  Task: Read the provided resume text below and generate a concise summary of the candidate's skills, formatted  │
# │  as a bulleted list. Resume Text: {'text': 'J U N A I D A B D U L\nLyonerstraße 42 | 60528 Frankfurt am         │
# │  Main\n0176 2035 3367 | deAbdulJunaid@gmail.com\nLinkedin :                                                     │
# │  https://www.linkedin.com/in/abduljunaid/\nGeburtsdatum: 02.04.1993\nAuftenthalstitel: EU Blaue Karte (in       │
# │  bearbeitung)\nFÄHIGKEITEN BERUFSERFAHRUNG\nTechnologien Detektiv bei der Ermittlungsbehörde des 01/20 –        │
# │  04/24\nBundesstaates Telangana ,Indien\n- Python: Umfassende Kenntnisse\n- SQL: Volle Arbeitskompetenz -       │
# │  Leitete und schulte ein Team von 5 Mitarbeitern über einen Zeitraum\nvon 2 Jahren und erreichte die höchste    │
# │  Fallabschlussrate im\n- Datenvisualisierung: Praktische\nBundesstaat (außerhalb der Großstadt                  │
# │  Grenzen)\nAnwendung von Matplotlib, Seaborn\n- Ich habe einen zentralen Datenspeicherungsprozess zur\n-        │
# │  Datenbereinigung: Umfassende\nSpeicherung und Verarbeitung von Kriminalakten im gesamten\nKenntnisse mit       │
# │  NumPy & Pandas\nBezirk, dem ich zugewiesen war, initiiert.\n- Classical ML                                     │
# │  (Regression,\nKlassifikation,Clustering): - Planung von Staffing & Ressourcen der Projekte                     │
# │  entsprechend\nUmfassende Kenntnisse Verfügbarkeit und benötigter Skills\n- NLP: Umfassende Kenntnisse -        │
# │  Arbeitete an einem Datenverarbeitungsalgorithmus für das\nGesichtserkennungstool.\n- Deep Learning:            │
# │  Umfassende\nKenntnisse - Praktische Erfahrung im Umgang mit KI                                                 │
# │  basierte\nBildverarbeitungswerkzeugen\nMethodische Kompetenzen\n- Agiles Projektmanagement (Scrum,\nKanban)    │
# │  System Analyst bei Tata Consultancy Services, 08/15 – 11/19\n- Business-Analyse & Hyderabad,                   │
# │  Indien\nAnforderungsmanagement\n- Durchführung einer vierteljährlichen Umstellung vom Rechenzentrum\n-         │
# │  Prozessmodelierung (BPMN 2.0) auf die Datenwiederherstellung\n- Demos,aufwandsschätzungen - Verwaltung und     │
# │  Monitoring von Oracle-Datenbankservern und JBoss-\n- Teamführung & Coaching Servern\n- User Stories schreiben  │
# │  für Implementierung des Oracle Order and\nAUSBILDUNG Service Management (OSM)-Tools\nM. Sc. Information        │
# │  Engineering - Durchführung von Demos und Aufwandsschätzungen für die\nFH Kiel Apr 2024 – umgesetzte            │
# │  Tools\nAktuell - Onboarding und wissensübergabe an junioren Team mitglieder.\nB. Sc.                           │
# │  ElektonikIngeniuerwesen\n- Verantwortlich für die Deployments und für die Hypercare\nGRIET,Hyderabad,Indien    │
# │  Sep 2011 – (Fehlerbehebung nach dem Launch/Go-live)\nJun 2015\nZERTIFIZIERUNGEN PROJEKTE\nMicrosoft            │
# │  certified: Power Mein PowerBI personilisierte Dashboard portfolio ist hier zu finden:\nBI Data Analyst         │
# │  Associate\nLink zum Dashboard\nMeine erfahrung mit Power BI ist auf mein learn.mircosoft Profil zu\nfinden:    │
# │  Link zum Profil\nPraktische erfahrung mit deployment tools ist auf mein GitHub\nProfil zu finden: Link zum     │
# │  Profil\nSPRACHEN TOOLS\nPower BI : Fortgeschnittene (zertifiziert)\nHindi(Muttersprache)\nDeutsch              │
# │  (Grundkenntnisse) JIRA, Confluence : Volle Arbeitskompetenz\nEnglisch (Verhandlungssicher) VisualStudio Code   │
# │  : Volle Arbeitskompetenz\nTelugu (Verhandlungssicher)\nGithub : Volle Arbeitskompetenz\nMiro, Lucidchart :     │
# │  Volle Arbeitskompetenz', 'tables': [[[''], ['']]]}                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resume Reader                                                                                           │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  - **Technical Skills:**                                                                                        │
# │    - Python: Comprehensive knowledge                                                                            │
# │    - SQL: Full working proficiency                                                                              │
# │    - Data Visualization: Practical experience with Matplotlib and Seaborn                                       │
# │    - Data Cleaning: Extensive knowledge with NumPy & Pandas                                                     │
# │    - Classical Machine Learning: Comprehensive knowledge (Regression, Classification, Clustering)               │
# │    - Natural Language Processing: Comprehensive knowledge                                                       │
# │    - Deep Learning: Comprehensive knowledge                                                                     │
# │    - Agile Project Management: (Scrum, Kanban)                                                                  │
# │    - Business Analysis & Requirements Management                                                                │
# │    - Process Modeling: BPMN 2.0                                                                                 │
# │    - Oracle Database Management: Administration and monitoring                                                  │
# │    - Tools: JIRA, Confluence, Visual Studio Code, GitHub, Miro, Lucidchart                                      │
# │    - Deployment Tools: Practical experience                                                                     │
# │                                                                                                                 │
# │  - **Soft Skills:**                                                                                             │
# │    - Team Leadership & Coaching                                                                                 │
# │    - Project Staffing & Resource Planning                                                                       │
# │    - User Story Creation                                                                                        │
# │    - Demos & Estimation Management                                                                              │
# │    - Onboarding & Knowledge Transfer                                                                            │
# │                                                                                                                 │
# │  - **Certifications:**                                                                                          │
# │    - Microsoft Certified: Power BI Data Analyst Associate                                                       │
# │                                                                                                                 │
# │  - **Languages:**                                                                                               │
# │    - Hindi: Native                                                                                              │
# │    - English: Fluent                                                                                            │
# │    - Telugu: Fluent                                                                                             │
# │    - German: Basic knowledge                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: afea163d-1806-4786-a98e-a8d47566c654                                                                     │
# │  Agent: Resume Reader                                                                                           │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Job Description Analyst                                                                                 │
# │                                                                                                                 │
# │  Task: Read the job description text below. Summarize the key skills and qualifications required for the role.  │
# │  Job Description Text:                                                                                          │
# │  Responsibilities                                                                                               │
# │                                                                                                                 │
# │  Advise clients on AI and data strategy from pilot to enterprise adoption                                       │
# │  Define AI roadmaps and oversee delivery across industries                                                      │
# │  Build relationships with senior business leaders                                                               │
# │  Lead teams in designing and deploying innovative AI solutions                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Requirements                                                                                                   │
# │                                                                                                                 │
# │  Experience in analytics, data science, or AI strategy                                                          │
# │  Strong knowledge of cloud ecosystems and AI tools                                                              │
# │  Excellent stakeholder engagement skills                                                                        │
# │  Background in consulting or advisory roles                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Benefits                                                                                                       │
# │                                                                                                                 │
# │  Salary up to €90,000                                                                                           │
# │  Access to major enterprises across finance, healthcare, and automotive                                         │
# │  Career development in a growing AI practice                                                                    │
# │  Flexible work setup within an international team                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Job Description Analyst                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The required skills and qualifications for the role include:                                                   │
# │                                                                                                                 │
# │  - **Technical Skills:**                                                                                        │
# │    - Proficient experience in analytics, data science, or AI strategy.                                          │
# │    - Strong knowledge of cloud ecosystems and familiarity with AI tools.                                        │
# │    - Practical knowledge of programming languages such as Python and SQL.                                       │
# │    - Experience with data visualization techniques, utilizing libraries like Matplotlib and Seaborn.            │
# │    - Extensive expertise in data cleaning with tools including NumPy and Pandas.                                │
# │    - Comprehensive understanding of classical machine learning algorithms including regression,                 │
# │  classification, and clustering.                                                                                │
# │    - Deep learning knowledge to contribute to AI solution development.                                          │
# │                                                                                                                 │
# │  - **Project Management Skills:**                                                                               │
# │    - Experience in Agile Project Management methodologies such as Scrum and Kanban.                             │
# │    - Capable of leading teams effectively and managing project staffing and resource planning.                  │
# │                                                                                                                 │
# │  - **Soft Skills:**                                                                                             │
# │    - Excellent stakeholder engagement skills to build relationships with senior business leaders.               │
# │    - Strong team leadership and coaching abilities.                                                             │
# │    - User story creation and effective communication skills for onboarding and knowledge transfer.              │
# │                                                                                                                 │
# │  - **Consulting Background:**                                                                                   │
# │    - Prior experience in consulting or advisory roles is highly valued, demonstrating an understanding of       │
# │  client needs and strategic advisement.                                                                         │
# │                                                                                                                 │
# │  - **Certifications:**                                                                                          │
# │    - Relevant certifications such as Microsoft Certified: Power BI Data Analyst Associate are advantageous.     │
# │                                                                                                                 │
# │  - **Languages:**                                                                                               │
# │    - Fluency in English, along with proficiency in Hindi and Telugu, and basic knowledge of German is           │
# │  beneficial to engage with diverse clients and teams.                                                           │
# │                                                                                                                 │
# │  This role offers benefits including a competitive salary up to €90,000, opportunities to work with major       │
# │  enterprises across various industries (finance, healthcare, and automotive), career development within a       │
# │  growing AI practice, and a flexible work setup within an international team.                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: a9d9f241-6679-4cb4-a132-b4c7172a6b0a                                                                     │
# │  Agent: Job Description Analyst                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Profile Matcher                                                                                         │
# │                                                                                                                 │
# │  Task: Compare the skills from the resume summary with the required skills from the job description summary.    │
# │  Based on the comparison, classify the candidate's profile into one of three categories: 'Best Match', 'OK to   │
# │  Go', or 'Irrelevant Profile'. Provide a brief, one-sentence justification for your classification. Resume      │
# │  Skills:                                                                                                        │
# │  Job Description Skills:                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Profile Matcher                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Best Match - The candidate possesses comprehensive knowledge and practical experience in all required          │
# │  technical skills, such as Python, SQL, data visualization, data cleaning, classical machine learning, and      │
# │  deep learning, alongside strong project management skills and relevant certifications, making them highly      │
# │  suitable for the role.                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 32e4e2dd-85c9-43f1-8038-9f3b4d4076fd                                                                     │
# │  Agent: Profile Matcher                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 82cda1dd-12b8-4fbf-97c9-7f9e79ac15d8                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Best Match - The candidate possesses comprehensive knowledge and practical experience in all     │
# │  required technical skills, such as Python, SQL, data visualization, data cleaning, classical machine           │
# │  learning, and deep learning, alongside strong project management skills and relevant certifications, making    │
# │  them highly suitable for the role.                                                                             │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(result.raw)
# Out:
# Best Match - The candidate possesses comprehensive knowledge and practical experience in all required technical skills, such as Python, SQL, data visualization, data cleaning, classical machine learning, and deep learning, alongside strong project management skills and relevant certifications, making them highly suitable for the role.
